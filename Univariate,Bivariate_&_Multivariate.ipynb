# %% [markdown]
# <a href="https://colab.research.google.com/github/manojnahak02/Univariate-Bivariate-Multivariate/blob/master/Univariate%2CBivariate_%26_Multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
d = {'a':1, 'b':2, 'c':3}
for key, value in d.items():
    print(f"{key}: {value}")
# Out:
# a: 1
# b: 2
# c: 3

# %%
t = 10,20,30
type(t)
# Out:
# tuple

# %%
t = (10)
type(t)
# Out:
# int

# %%
# if you want to define a one-element tuple, you must use a comma:
 t = (10,)
 type(t)
# Out:
# tuple

# %%
mylist = [10, 20, 30]
'*'.join(mylist)
#This fails, because the elements of “mylist” are integers.  We can use a generator expression to turn each integer into a string:

# %%
'*'.join(str(x)
for x in mylist)
# Out:
# '10*20*30'

# %%
person = {'first':'Reuven', 'last':'Lerner', 'email':'reuven@lerner.co.il'}
if 'e' in person['first'] or 'e' in person['last'] or 'e' in person['email']:
  print("Found it!")
# Out:
# Found it!

# %%
person = {'first':'Reuven', 'last':'Lerner', 'email':'reuven@lerner.co.il'}
if 'e' in person['first']or 
   'e' in person['last']or
   'e' in person['email']:
   print("Found it!")

#below code is the solution of this error
# Out:
#   File "<ipython-input-27-9f0743fa08a1>", line 2
#     if 'e' in person['first']or
#                                 ^
# SyntaxError: invalid syntax

# %%
if ('e' in person['first']or 
   'e' in person['last']or
   'e' in person['email']):
   print("Found it!")
# Out:
# Found it!

# %%
#Univariate Analysis

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Getting the values were species is setosa,virginica,versicolor
df_setosa = df.loc[df['species']=='setosa']
df_virginica = df.loc[df['species']=='virginica']
df_versicolor = df.loc[df['species']=='versicolor']

# %%
#creating a univariate diagram, so will make Y as 0
#Syntax plt.plot(df_setosa['sepal_length'],np.zero_like(specify the length how many 0 will come in y variable))
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']))
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']))
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']))
plt.xlabel('petal_length')
plt.show()

# %%
#to make the image more visible, we can gine a parameter as 'o' in last
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel('petal_length')
plt.show()

# %%
#Bivariate Analysis

# %%
sns.FacetGrid(df,hue='species',size=5).map(plt.scatter,'sepal_length','sepal_width').add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df,hue='species',size=5).map(plt.scatter,'petal_length','sepal_width').add_legend();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#For more than 3 feature we use MULTIVARIATE Analysis

# %%
sns.pairplot(df,hue='species',size=3)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
